# %% [markdown]
# ## <span style="color:#db7d60">Setup</span>

# %%
# %load_ext autoreload
# %autoreload 2

import json
import math
import pickle
import numpy as np
import pandas as pd
import textwrap
import sys
from pathlib import Path
from IPython.display import display, Markdown
import matplotlib.pyplot as plt

# pUtil needs to be loaded from the root directory
parent_dir = Path().resolve().parent
sys.path.insert(0, str(parent_dir))

import pUtil
from analysis_common import *
import analysis as anal

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## <span style="color:#db7d60">Tests</span>

# %%
models_to_compare = ['model_5_9_1']
anal.plotting.plot_training_run(models_to_compare)
anal.plotting.plot_training_run(models_to_compare, y_lim=[4.4, 5.3], use_log=True)
models_to_compare = ['model_5_9_1', 'model_5_9_2']
anal.plotting.plot_training_run(models_to_compare, y_lim=[4.4, 5.3], use_log=True)
models_to_compare = ['model_5_9_1', 'model_5_9_2', 'model_5_10_1']
anal.plotting.plot_training_run(models_to_compare)
# Out:
# (<Figure size 6300x1800 with 1 Axes>, <Axes: >)

# %%
models_to_compare = ['model_5_5_1', 'model_5_5_5']
anal.plotting.plot_pdgid_distribution_leading(models_to_compare)
anal.plotting.plot_pdgid_distribution_leading(models_to_compare, use_log=True)
# Out:
# (<Figure size 6300x2400 with 1 Axes>, <Axes: >)

# %%
models_to_compare = ['model_5_5_1', 'model_5_5_5']
anal.plotting.plot_pdgid_distribution_all(models_to_compare, use_log=True)
# Out:
# (<Figure size 6300x2400 with 1 Axes>, <Axes: >)
